# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#untuk membaca file csv
df =pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.gender.value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
df = df.drop(df[df['gender'] == 'Other'].index).reset_index(drop=True)

# %%
df.gender.value_counts()
# Out:
# Female    2994
# Male      2115
# Name: gender, dtype: int64

# %%
df.age.value_counts()
# Out:
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 1.40       3
# 0.48       3
# 0.16       3
# 0.40       2
# 0.08       2
# Name: age, Length: 104, dtype: int64

# %%
# melakukan pembulatan untuk usia jika 35.4 jadi 35 , 25,5 jadi 26 , <1 jadi 1 dan 0 menjadi 1
df = pd.DataFrame(df)
df['age'] = df['age'].apply(lambda x: max(round(x), 1))
print(df)
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5104  18234  Female   80             1              0          Yes
# 5105  44873  Female   81             0              0          Yes
# 5106  19723  Female   35             0              0          Yes
# 5107  37544    Male   51             0              0          Yes
# 5108  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
df.age.value_counts()
# Out:
# 78    102
# 57     95
# 2      90
# 52     90
# 54     87
#      ...
# 11     36
# 10     35
# 4      34
# 7      32
# 6      24
# Name: age, Length: 82, dtype: int64

# %%
pd.unique(df['age'])
# Out:
# array([67, 61, 80, 49, 79, 81, 74, 69, 59, 78, 54, 50, 64, 75, 60, 57, 71,
#        52, 82, 65, 58, 42, 48, 72, 63, 76, 39, 77, 73, 56, 45, 70, 66, 51,
#        43, 68, 47, 53, 38, 55,  1, 46, 32, 14,  3,  8, 37, 40, 35, 20, 44,
#        25, 27, 23, 17, 13,  4, 16, 22, 30, 29, 11, 21, 18, 33, 24, 34, 36,
#        41,  5, 26, 31,  7, 12, 62,  2,  9, 15, 28, 10, 19,  6],
#       dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5109 entries, 0 to 5108
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5109 non-null   int64
#  1   gender             5109 non-null   object
#  2   age                5109 non-null   int64
#  3   hypertension       5109 non-null   int64
#  4   heart_disease      5109 non-null   int64
#  5   ever_married       5109 non-null   object
#  6   work_type          5109 non-null   object
#  7   Residence_type     5109 non-null   object
#  8   avg_glucose_level  5109 non-null   float64
#  9   bmi                4908 non-null   float64
#  10  smoking_status     5109 non-null   object
#  11  stroke             5109 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 479.1+ KB

# %%
df.hypertension.value_counts()
# Out:
# 0    4611
# 1     498
# Name: hypertension, dtype: int64

# %%
df.heart_disease.value_counts()
# Out:
# 0    4833
# 1     276
# Name: heart_disease, dtype: int64

# %%
df.ever_married.value_counts()
# Out:
# Yes    3353
# No     1756
# Name: ever_married, dtype: int64

# %%
# mengubah "Yes" dan "No" value menjadi 1 dan 0
df.loc[df["ever_married"] == "No", "ever_married"] = 0
df.loc[df["ever_married"] == "Yes", "ever_married"] = 1

# %%
df.ever_married.value_counts()
# Out:
# 1    3353
# 0    1756
# Name: ever_married, dtype: int64

# %%
df.work_type.value_counts()
# Out:
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
df.Residence_type.value_counts()
# Out:
# Urban    2596
# Rural    2513
# Name: Residence_type, dtype: int64

# %%
df.avg_glucose_level.value_counts()
# Out:
# 93.88     6
# 91.68     5
# 91.85     5
# 83.16     5
# 73.00     5
#          ..
# 94.07     1
# 111.93    1
# 94.40     1
# 95.57     1
# 85.28     1
# Name: avg_glucose_level, Length: 3978, dtype: int64

# %%
df.bmi.value_counts()
# Out:
# 28.7    41
# 28.4    38
# 26.7    37
# 27.6    37
# 26.1    37
#         ..
# 48.7     1
# 49.2     1
# 51.0     1
# 49.4     1
# 14.9     1
# Name: bmi, Length: 418, dtype: int64

# %%
df.smoking_status.value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: smoking_status, dtype: int64

# %%
df.stroke.value_counts()
# Out:
# 0    4860
# 1     249
# Name: stroke, dtype: int64

# %%
# melihat data duplikat
df.duplicated().sum()
# Out:
# 0

# %%
# menghapus kolom 'id' karena tidak diperlukan dalam proses
df = df.drop(['id'], axis=1)

# %%
# melihat missing value
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# melihat data yang missing di bmi
df[df['bmi'].isnull()]
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 1     Female   61             0              0            1  Self-employed
# 8     Female   59             0              0            1        Private
# 13      Male   78             0              1            1        Private
# 19      Male   57             0              1            0       Govt_job
# 27      Male   58             0              0            1        Private
# ...      ...  ...           ...            ...          ...            ...
# 5038    Male   41             0              0            0        Private
# 5047    Male   40             0              0            1        Private
# 5092  Female   45             1              0            1       Govt_job
# 5098    Male   40             0              0            1        Private
# 5104  Female   80             1              0            1        Private
#
#      Residence_type  avg_glucose_level  bmi   smoking_status  stroke
# ...

# %%
#menghapus data yang null
df.dropna(inplace=True)

# %%
# cek ulang apakah datanya sudah terapus atau belum
df[df['bmi'].isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4908.000000   4908.000000    4908.000000        4908.000000
# mean     42.872861      0.091891       0.049511         105.297402
# std      22.548603      0.288901       0.216954          44.425550
# min       1.000000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.067500
# 50%      44.000000      0.000000       0.000000          91.680000
# 75%      60.000000      0.000000       0.000000         113.495000
# max      82.000000      1.000000       1.000000         271.740000
#
#               bmi       stroke
# count  4908.00000  4908.000000
# mean     28.89456     0.042584
# std       7.85432     0.201937
# min      10.30000     0.000000
# 25%      23.50000     0.000000
# 50%      28.10000     0.000000
# 75%      33.10000     0.000000
# max      97.60000     1.000000

# %%
# persentase stroke distribution
stroke_counts = df['stroke'].value_counts()
plt.pie(stroke_counts, labels=stroke_counts.index,autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'] )
plt.title('Stroke Distribution')
# Out:
# Text(0.5, 1.0, 'Stroke Distribution')

# %%
# jumlah data dari setiap variasi data pada kolom
fig,axes = plt.subplots(4,2,figsize = (16,16))
sns.set_style('whitegrid')
fig.suptitle("Count plot for various categorical features")

sns.countplot(ax=axes[0,0],data=df,x='gender')
sns.countplot(ax=axes[0,1],data=df,x='hypertension')
sns.countplot(ax=axes[1,0],data=df,x='heart_disease')
sns.countplot(ax=axes[1,1],data=df,x='ever_married')
sns.countplot(ax=axes[2,0],data=df,x='work_type')
sns.countplot(ax=axes[2,1],data=df,x='Residence_type')
sns.countplot(ax=axes[3,0],data=df,x='smoking_status')
sns.countplot(ax=axes[3,1],data=df,x='stroke')

plt.show()

# %%
# melihat hubungan `work_type` dengan `avg_glucose_level`
df.groupby(['work_type'])['avg_glucose_level'].median().plot(kind = 'bar')
plt.show()

# %%
# melihat hubungan `work_type` dengan `bmi`
df.groupby(['work_type'])['bmi'].median().plot(kind = 'bar')
plt.show()

# %%
corr = df.corr().round(2)
plt.figure(figsize = (5,4))
sns.heatmap(corr, annot = True, cmap = 'YlOrBr')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_29228\3735556954.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr().round(2)
# <Axes: >

# %%
# melihat pesebaran data menggunakan Histogram
fig = plt.figure()
ax = sns.histplot(x=df['age'], kde=True, color='blue')

plt.title("age distribution")
plt.xlabel("bmi")
# Out:
# Text(0.5, 0, 'bmi')

# %%
# melihat pesebaran data menggunakan Histogram
fig = plt.figure()
ax = sns.histplot(x=df['avg_glucose_level'], kde=True, color='darkblue')

plt.title("avg_glucose_level distribution")
plt.xlabel("avg_glucose_level")
# Out:
# Text(0.5, 0, 'avg_glucose_level')

# %%
# melihat pesebaran data menggunakan Histogram
fig = plt.figure()
ax = sns.histplot(x=df['bmi'], kde=True, color='blue')

plt.title("bmi distribution")
plt.xlabel("bmi")
# Out:
# Text(0.5, 0, 'bmi')

# %%
# pesebaran data tipe pekerjaan
fig = plt.figure(figsize=(8, 6))
ax = sns.countplot(y=df['work_type'])

plt.title("work type")
plt.xlabel("Jumlah")
plt.ylabel("pekerjaan")
# Out:
# Text(0, 0.5, 'pekerjaan')

# %%
# Bivariate
# Filter data to include only rows where 'stroke' is 1
df_stroke = df[df['stroke'] == 1]

# Create subplots for smoking_status, gender, hypertension, heart_disease, work_type, ever_married, and Residence_type
plt.figure(figsize=(30, 16))  # Adjusting the figure height

# Subplot 1: gender
plt.subplot(2, 4, 1)
sns.countplot(x='gender', hue='stroke', data=df, palette='viridis')
plt.title('gender vs stroke')
plt.xlabel('Gender')
plt.ylabel('Count')

# Subplot 2: Hypertension
plt.subplot(2, 4, 2)
sns.countplot(x='hypertension', hue='stroke', data=df, palette='viridis')
plt.title('hypertension vs stroke')
plt.xlabel('Hypertension')
plt.ylabel('Count')

# Subplot 3: Heart disease
plt.subplot(2, 4, 3)
sns.countplot(x='heart_disease', hue='stroke', data=df, palette='viridis')
plt.title('Heart Disease vs stroke')
plt.xlabel('Heart Disease')
plt.ylabel('Count')

# Subplot 4: ever married
plt.subplot(2, 4, 4)
sns.countplot(x='ever_married', hue='stroke', data=df, palette='viridis')
plt.title('Ever Married vs stroke')
plt.xlabel('Ever married')
plt.ylabel('Count')

# Subplot 5: Work Type
plt.subplot(2, 4, 5)
sns.countplot(x='work_type', hue='stroke', data=df, palette='viridis')
plt.title('Work Type vs stroke')
plt.xlabel('work type')
plt.ylabel('Count')

# Subplot 6: Residence type
plt.subplot(2, 4, 6)
sns.countplot(x='Residence_type', hue='stroke', data=df, palette='viridis')
plt.title('Residence type vs stroke')
plt.xlabel('Residence type')
plt.ylabel('Count')

# Subplot 7: smoking status
plt.subplot(2, 4, 7)
sns.countplot(x='smoking_status', hue='stroke', data=df, palette='viridis')
plt.title('Smoking status vs stroke')
plt.xlabel('Smoking status')
plt.ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the combined chart
plt.show()

# %%
#univariate
# Filter data to include only rows where 'stroke' is 1
df_stroke = df[df['stroke'] == 1]

# Create subplots for smoking_status, gender, hypertension, heart_disease, work_type, ever_married, and Residence_type
plt.figure(figsize=(30, 16))  # Menyesuaikan tinggi figur

# Subplot 1: Smoking Status
plt.subplot(2, 4, 1)
sns.countplot(x='smoking_status', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('Count')

# Subplot 2: Gender
plt.subplot(2, 4, 2)
sns.countplot(x='gender', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Subplot 3: Hypertension
plt.subplot(2, 4, 3)
sns.countplot(x='hypertension', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Hypertension')
plt.xlabel('Hypertension')
plt.ylabel('Count')

# Subplot 4: Heart Disease
plt.subplot(2, 4, 4)
sns.countplot(x='heart_disease', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Heart Disease')
plt.xlabel('Heart Disease')
plt.ylabel('Count')

# Subplot 5: Work Type
plt.subplot(2, 4, 5)
sns.countplot(x='work_type', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Work Type')
plt.xlabel('Work Type')
plt.ylabel('Count')

# Subplot 6: Ever Married
plt.subplot(2, 4, 6)
sns.countplot(x='ever_married', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Ever Married')
plt.xlabel('Ever Married')
plt.ylabel('Count')

# Subplot 7: Residence Type
plt.subplot(2, 4, 7)
sns.countplot(x='Residence_type', data=df_stroke, palette='viridis', hue='stroke')
plt.title('Stroke Count by Residence Type')
plt.xlabel('Residence Type')
plt.ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the combined chart
plt.show()

# %%
# multivariate
# untuk melihat persebaran data
sns.pairplot(df, hue="stroke")
plt.show()

# %%
# melihat pesebaran data menggunakan boxplot(outlier)
fig = plt.figure()
ax = sns.boxplot(x='bmi', data=df, color='#bd8ad4')

plt.title("bmi")
plt.xlabel("bmi")

plt.show()
# yang ada di pinggiran kota ungu sebelah kiri itu q1 Q2= garis tengah Q3= garis kanan kotak ungu
# outlier itu data yang keluar jalur atau tidak sesuai dengan data2 kebanyakan

# %%
# melihat pesebaran data menggunakan boxplot(outlier)
fig = plt.figure()
ax = sns.boxplot(x='avg_glucose_level', data=df, color='#bd8ad4')

plt.title("glukosa")
plt.xlabel("glucose level")

plt.show()
# yang ada di pinggiran kota ungu sebelah kiri itu q1 Q2= garis tengah Q3= garis kanan kotak ungu
# outlier itu data yang keluar jalur atau tidak sesuai dengan data2 kebanyakan
